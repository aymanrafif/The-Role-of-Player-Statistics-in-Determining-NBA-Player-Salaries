# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data\players_stats_complete_and_contract.csv')

# %%
df.sample(10)
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 339      Aaron Holiday  PG   26  ATL  63   6  13.4  1.5   3.5  0.418  ...
# 188       Shake Milton  SG   26  PHI  76  11  20.6  3.2   6.6  0.479  ...
# 374    Jalen McDaniels  SF   25  TOT  80  24  23.9  3.5   7.7  0.455  ...
# 68       DeMar DeRozan  SF   33  CHI  74  74  36.2  8.9  17.6  0.504  ...
# 239   Orlando Robinson   C   22  MIA  31   1  13.7  1.5   2.9  0.528  ...
# 155     Furkan Korkmaz  SG   25  PHI  37   0   9.5  1.3   3.0  0.432  ...
# 280  Jarred Vanderbilt  PF   23  TOT  78  65  24.1  3.2   5.8  0.548  ...
# 181       JaVale McGee   C   35  DAL  42   7   8.5  1.9   3.0  0.640  ...
# 253      Pascal Siakam  PF   28  TOR  71  71  37.4  8.9  18.5  0.480  ...
# 55     Jordan Clarkson  SG   30  UTA  61  61  32.6  7.5  16.9  0.444  ...
#
#      USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP      2023-24
# 339  13.4  0.3  0.6  0.9  0.053  -2.9   0.9 -2.0   0.0   $2,019,706
# 188  18.5  1.6  1.2  2.9  0.087  -1.0  -0.9 -2.0   0.0   $5,000,000
# 374  17.2  0.5  2.2  2.7  0.068  -2.7   0.6 -2.1  -0.1   $4,516,000
# 68   27.8  5.4  3.2  8.5  0.153   1.7   0.3  2.0   2.6  $28,600,000
# 239  12.4  0.5  0.6  1.1  0.129  -2.7   0.7 -2.1   0.0   $1,801,769
# 155  19.1 -0.2  0.3  0.1  0.019  -3.3  -1.0 -4.4  -0.2   $5,370,370
# 280  13.6  2.7  2.5  5.2  0.132  -0.6   1.6  1.1   1.5   $4,698,000
# 181  22.8  0.1  0.5  0.6  0.076  -3.6  -0.1 -3.7  -0.1   $5,734,280
# 253  27.2  5.2  2.6  7.8  0.141   3.3  -0.1  3.1   3.4  $37,893,408
# 55   27.8  0.9  0.8  1.7  0.042   1.0  -2.4 -1.4   0.3  $23,487,629
#
# [10 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 50 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   393 non-null    object
#  1   Pos      393 non-null    object
#  2   Age      393 non-null    int64
#  3   Tm       393 non-null    object
#  4   G        393 non-null    int64
#  5   GS       393 non-null    int64
#  6   MP       393 non-null    float64
#  7   FG       393 non-null    float64
#  8   FGA      393 non-null    float64
#  9   FG%      393 non-null    float64
#  10  3P       393 non-null    float64
#  11  3PA      393 non-null    float64
#  12  3P%      388 non-null    float64
#  13  2P       393 non-null    float64
#  14  2PA      393 non-null    float64
#  15  2P%      393 non-null    float64
#  16  eFG%     393 non-null    float64
#  17  FT       393 non-null    float64
#  18  FTA      393 non-null    float64
#  19  FT%      393 non-null    float64
#  20  ORB      393 non-null    float64
#  21  DRB      393 non-null    float64
#  22  TRB      393 non-null    float64
#  23  AST      393 non-null    float64
#  24  STL      393 non-null    float64
#  25  BLK      393 non-null    float64
#  26  TOV      393 non-null    float64
#  27  PF       393 non-null    float64
#  28  PTS      393 non-null    float64
#  29  PER      393 non-null    float64
#  30  TS%      393 non-null    float64
#  31  3PAr     393 non-null    float64
#  32  FTr      393 non-null    float64
#  33  ORB%     393 non-null    float64
#  34  DRB%     393 non-null    float64
#  35  TRB%     393 non-null    float64
#  36  AST%     393 non-null    float64
#  37  STL%     393 non-null    float64
#  38  BLK%     393 non-null    float64
#  39  TOV%     393 non-null    float64
#  40  USG%     393 non-null    float64
#  41  OWS      393 non-null    float64
#  42  DWS      393 non-null    float64
#  43  WS       393 non-null    float64
#  44  WS/48    393 non-null    float64
#  45  OBPM     393 non-null    float64
#  46  DBPM     393 non-null    float64
#  47  BPM      393 non-null    float64
#  48  VORP     393 non-null    float64
#  49  2023-24  393 non-null    object
# dtypes: float64(43), int64(3), object(4)
# memory usage: 153.6+ KB

# %%
df.rename(columns = {'2023-24':'Salary'}, inplace = True)
df.head(5)
# Out:
#              Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  USG%  \
# 0  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  0.485  ...  19.4
# 1      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  0.597  ...  14.6
# 2       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  0.540  ...  25.2
# 3      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  0.427  ...  15.8
# 4      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  0.470  ...  16.0
#
#    OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP       Salary
# 0  0.8  1.4  2.2  0.093  -1.4  -0.8 -2.3  -0.1   $4,379,527
# 1  1.3  2.1  3.4  0.144  -0.3   0.9  0.6   0.7  $12,600,000
# 2  3.6  3.8  7.4  0.137   0.8   0.8  1.5   2.3  $32,600,060
# 3  0.9  0.4  1.3  0.053  -1.7  -1.4 -3.0  -0.3   $4,114,200
# 4  2.1  2.4  4.6  0.130  -0.3   0.8  0.5   1.1   $2,194,200
#
# [5 rows x 50 columns]

# %%
df['Salary'] = df['Salary'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df.head(5)
# Out:
#              Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  USG%  \
# 0  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  0.485  ...  19.4
# 1      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  0.597  ...  14.6
# 2       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  0.540  ...  25.2
# 3      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  0.427  ...  15.8
# 4      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  0.470  ...  16.0
#
#    OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP      Salary
# 0  0.8  1.4  2.2  0.093  -1.4  -0.8 -2.3  -0.1   4379527.0
# 1  1.3  2.1  3.4  0.144  -0.3   0.9  0.6   0.7  12600000.0
# 2  3.6  3.8  7.4  0.137   0.8   0.8  1.5   2.3  32600060.0
# 3  0.9  0.4  1.3  0.053  -1.7  -1.4 -3.0  -0.3   4114200.0
# 4  2.1  2.4  4.6  0.130  -0.3   0.8  0.5   1.1   2194200.0
#
# [5 rows x 50 columns]

# %%
df_numeric = df.drop(['Player', 'Pos','Tm'], axis=1)

# %%
df_numeric.head(5)
# Out:
#    Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  USG%  OWS  DWS  \
# 0   23  55  12  20.7  3.6   7.3  0.485  0.5  2.0  0.269  ...  19.4  0.8  1.4
# 1   29  42  42  27.0  3.7   6.3  0.597  0.0  0.0  0.000  ...  14.6  1.3  2.1
# 2   25  75  75  34.6  8.0  14.9  0.540  0.0  0.2  0.083  ...  25.2  3.6  3.8
# 3   22  59  22  20.5  2.8   6.5  0.427  1.4  3.9  0.355  ...  15.8  0.9  0.4
# 4   22  77  20  21.8  3.2   6.8  0.470  1.2  3.5  0.353  ...  16.0  2.1  2.4
#
#     WS  WS/48  OBPM  DBPM  BPM  VORP      Salary
# 0  2.2  0.093  -1.4  -0.8 -2.3  -0.1   4379527.0
# 1  3.4  0.144  -0.3   0.9  0.6   0.7  12600000.0
# 2  7.4  0.137   0.8   0.8  1.5   2.3  32600060.0
# 3  1.3  0.053  -1.7  -1.4 -3.0  -0.3   4114200.0
# 4  4.6  0.130  -0.3   0.8  0.5   1.1   2194200.0
#
# [5 rows x 47 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a larger figure
plt.figure(figsize=(30, 15))

# Plot the heatmap for correlation
ax = sns.heatmap(df_numeric.corr(), annot=True)

# Display the plot
plt.show()

# %%
plt.hist(df['MP'], bins=20, color='skyblue', edgecolor='black')

# Add labels and a title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Data Distribution')
# Out:
# Text(0.5, 1.0, 'Histogram of Data Distribution')
